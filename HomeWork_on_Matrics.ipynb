# %%
import numpy as np
import matplotlib.pyplot as plt
#Seasons
Seasons= ["2005","2006","2007","2008","2009","2010","2011","2012","2013","2014"]
Sdict = {"2005":0,"2006":1,"2007":2,"2008":3,"2009":4,"2010":5,"2011":6,"2012":7,"2013":8,"2014":9,"2015":10}
#Players
Players = ["KobeBryant", "JoeJohnson", "LeBranJames", "CarmeloAntbony", "DwightHoward", "Chrisbosh","ChrisPaul", "KevinDurant", "DerricRose", "DwayneWade"]
Pdict = {"KobeBryant":0, "JoeJohnson":1, "LeBranJames":2, "CarmeloAntbony":3, "DwightHoward":4, "Chrisbosh":5,"ChrisPaul":6, "KevinDurant":7, "DerricRose":8, "DwayneWade":9}
# Free Throws
KobeBryant_FT =[696, 667, 623, 483, 439, 483, 381, 525, 18, 196 ] 
JoeJohnson_FT =[261, 235, 316, 299, 220, 195, 158, 132, 159, 141 ]
LeBranJames_FT =[601, 489, 549, 594, 593, 503, 387, 403, 439, 375]
CarmeloAntbony_FT =[573, 459, 464, 371, 508, 507, 295, 425, 459, 189 ]
DwightHoward_FT =[356, 390, 529, 504, 483, 546, 281, 355, 349, 143 ]
ChrisBosh_FT= [474, 463, 472, 504, 470, 384, 229, 241, 223, 179 ]
ChrisPaul_FT= [394, 292, 332, 455, 161, 337, 260, 286, 295, 289 ]
KevinDurant_FT= [209, 209, 391, 452, 756, 594, 431, 679, 703, 146 ]
DerricRose_FT= [146, 146, 146, 197, 259, 476, 194, 0, 27, 152 ]
DwayneWade_FT= [629, 432, 354, 590, 534, 494, 235, 308, 189, 284 ]

# Matrix
#
FreeThrows= np.array([KobeBryant_FT, JoeJohnson_FT, LeBranJames_FT, CarmeloAntbony_FT, DwightHoward_FT, ChrisBosh_FT, ChrisPaul_FT, KevinDurant_FT, DerricRose_FT, DwayneWade_FT])
#creating vector
#FreeThrows= _([KobeBryant_FT, JoeJohnson_FT, LeBranJames_FT, CarmeloAntbony_FT, DwightHoward_FT, ChrisBosh_FT, ChrisPaul_FT, KevinDurant_FT, DerricRose_FT, DwayneWade_FT])

# Free Throw Attempts

KobeBryant_FTA =[819, 768, 742, 564, 541, 583, 451, 626, 21, 241 ] 
JoeJohnson_FTA =[330, 314, 379, 362, 269, 243, 186, 161, 195, 176 ]
LeBranJames_FTA =[814, 701, 771, 762, 773, 663, 502, 535, 585, 528]
CarmeloAntbony_FTA =[709, 568, 590, 468, 612, 605, 367, 512, 541, 237 ]
DwightHoward_FTA =[598, 666, 897, 849, 816, 916, 572, 721, 638, 271 ]
ChrisBosh_FTA= [581, 590, 559, 617, 590, 471, 279, 302, 272, 232 ]
ChrisPaul_FTA= [465, 357, 390, 524, 190, 384, 302, 323, 345, 321 ]
KevinDurant_FTA= [256, 256, 448, 524, 840, 675, 501, 750, 805, 171 ]
DerricRose_FTA= [205, 205, 205, 250, 338, 555, 239, 0, 32, 187 ]
DwayneWade_FTA= [803, 535, 467, 771, 702, 652, 297, 425, 258, 370 ]

#Matrix
#
FreeThrowAttempts= np.array([KobeBryant_FTA, JoeJohnson_FTA, LeBranJames_FTA, CarmeloAntbony_FTA, DwightHoward_FTA, ChrisBosh_FTA, ChrisPaul_FTA, KevinDurant_FTA, DerricRose_FTA, DwayneWade_FTA])
#FreeThrowAttempts= _([KobeBryant_FTA, JoeJohnson_FTA, LeBranJames_FTA, CarmeloAntbony_FTA, DwightHoward_FTA, ChrisBosh_FTA, ChrisPaul_FTA, KevinDurant_FTA, DerricRose_FTA, DwayneWade_FTA])

# Remove vectors if we don't need anymore
# del(KobeBryant_FTA, JoeJohnson_FTA, LeBranJames_FTA, CarmeloAntbony_FTA, DwightHoward_FTA, ChrisBosh_FTA, ChrisPaul_FTA, KevinDurant_FTA, DerricRose_FTA, DwayneWade_FTA)

# %%
FreeThrowAttempts
# Out:
# array([[819, 768, 742, 564, 541, 583, 451, 626,  21, 241],
#        [330, 314, 379, 362, 269, 243, 186, 161, 195, 176],
#        [814, 701, 771, 762, 773, 663, 502, 535, 585, 528],
#        [709, 568, 590, 468, 612, 605, 367, 512, 541, 237],
#        [598, 666, 897, 849, 816, 916, 572, 721, 638, 271],
#        [581, 590, 559, 617, 590, 471, 279, 302, 272, 232],
#        [465, 357, 390, 524, 190, 384, 302, 323, 345, 321],
#        [256, 256, 448, 524, 840, 675, 501, 750, 805, 171],
#        [205, 205, 205, 250, 338, 555, 239,   0,  32, 187],
#        [803, 535, 467, 771, 702, 652, 297, 425, 258, 370]])

# %%
FreeThrows
# Out:
# array([[696, 667, 623, 483, 439, 483, 381, 525,  18, 196],
#        [261, 235, 316, 299, 220, 195, 158, 132, 159, 141],
#        [601, 489, 549, 594, 593, 503, 387, 403, 439, 375],
#        [573, 459, 464, 371, 508, 507, 295, 425, 459, 189],
#        [356, 390, 529, 504, 483, 546, 281, 355, 349, 143],
#        [474, 463, 472, 504, 470, 384, 229, 241, 223, 179],
#        [394, 292, 332, 455, 161, 337, 260, 286, 295, 289],
#        [209, 209, 391, 452, 756, 594, 431, 679, 703, 146],
#        [146, 146, 146, 197, 259, 476, 194,   0,  27, 152],
#        [629, 432, 354, 590, 534, 494, 235, 308, 189, 284]])

# %%
Pdict
# Out:
# {'KobeBryant': 0,
#  'JoeJohnson': 1,
#  'LeBranJames': 2,
#  'CarmeloAntbony': 3,
#  'DwightHoward': 4,
#  'Chrisbosh': 5,
#  'ChrisPaul': 6,
#  'KevinDurant': 7,
#  'DerricRose': 8,
#  'DwayneWade': 9}

# %%
Sdict
# Out:
# {'2005': 0,
#  '2006': 1,
#  '2007': 2,
#  '2008': 3,
#  '2009': 4,
#  '2010': 5,
#  '2011': 6,
#  '2012': 7,
#  '2013': 8,
#  '2014': 9,
#  '2015': 10}

# %%
FreeThrows
# Out:
# array([[696, 667, 623, 483, 439, 483, 381, 525,  18, 196],
#        [261, 235, 316, 299, 220, 195, 158, 132, 159, 141],
#        [601, 489, 549, 594, 593, 503, 387, 403, 439, 375],
#        [573, 459, 464, 371, 508, 507, 295, 425, 459, 189],
#        [356, 390, 529, 504, 483, 546, 281, 355, 349, 143],
#        [474, 463, 472, 504, 470, 384, 229, 241, 223, 179],
#        [394, 292, 332, 455, 161, 337, 260, 286, 295, 289],
#        [209, 209, 391, 452, 756, 594, 431, 679, 703, 146],
#        [146, 146, 146, 197, 259, 476, 194,   0,  27, 152],
#        [629, 432, 354, 590, 534, 494, 235, 308, 189, 284]])

# %%
def myplot(data,playerlist=Players):
    Col = {"KobeBryant":"red", "JoeJohnson":"yellow", "LeBranJames":"Blue", "CarmeloAntbony":"green", "DwightHoward":"magenta", "Chrisbosh":"purple","ChrisPaul":"orange", "KevinDurant":"red", "DerricRose":"brown", "DwayneWade":"violet"}
    Mrk = {"KobeBryant":"+", "JoeJohnson":"^", "LeBranJames":"*", "CarmeloAntbony":"8", "DwightHoward":"<", "Chrisbosh":">","ChrisPaul":"+", "KevinDurant":"^", "DerricRose":"*", "DwayneWade":"+"}
    Ls = {"KobeBryant":"--", "JoeJohnson":"-", "LeBranJames":"-.", "CarmeloAntbony":":", "DwightHoward":"--", "Chrisbosh":"-.","ChrisPaul":"-", "KevinDurant":":", "DerricRose":"-.", "DwayneWade":"-"}
    for name in playerlist:
        plt.plot(data[Pdict[name]], c=Col[name], ls=Ls[name], marker=Mrk[name], ms=7, label=Players[Pdict[name]])
    plt.legend(loc='Upper Left', bbox_to_anchor=(1,1))
    plt.xticks(list(range(0,10)), Seasons, rotation='vertical')
plt.show()

# %%
# _FreeThrows # not worked
#_FreeThrowAttempts

# %%
myplot(FreeThrows)
#plt.show()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\ipykernel_launcher.py:7: MatplotlibDeprecationWarning: Unrecognized location 'Upper Left'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.
#   import sys

# %%
myplot(FreeThrowAttempts)
#plt.show()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\ipykernel_launcher.py:7: MatplotlibDeprecationWarning: Unrecognized location 'Upper Left'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.
#   import sys

# %% [markdown]
# # Part 1

# %%
#Games
KobeBryant_G =[80, 77, 82, 82, 73, 82, 58, 78, 6, 35] 
JoeJohnson_G =[82, 57, 82, 79, 76, 72, 60, 72, 79, 80] 
LeBranJames_G =[79, 78, 75, 81, 76, 79, 62, 76, 77, 69] 
CarmeloAntbony_G =[80, 65, 77, 66, 69, 77, 55, 67, 77, 40] 
DwightHoward_G =[82, 82, 82, 79, 82, 78, 54, 76, 71, 41] 
Chrisbosh_G =[70, 69, 67, 77, 70, 77, 57, 74, 79, 44] 
Chrispaul_G =[78, 64, 80, 78, 45, 80, 60, 70, 62, 82] 
KevinDurant_G =[35, 35, 80, 74, 82, 78, 66, 81, 81, 27] 
DerricRose_G =[40, 40, 40, 81, 78, 81, 39, 0, 10, 51] 
DwayneWade_G =[75, 51, 51, 79, 77, 76, 49, 69, 54, 62] 

#Matrix
Games = np.array([KobeBryant_G, JoeJohnson_G, LeBranJames_G, CarmeloAntbony_G, DwightHoward_G, Chrisbosh_G, Chrispaul_G, KevinDurant_G, DerricRose_G, DwayneWade_G])

# %%
myplot(FreeThrowAttempts/Games)
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in true_divide
#   """Entry point for launching an IPython kernel.
# C:\Users\hp\anaconda3\lib\site-packages\ipykernel_launcher.py:7: MatplotlibDeprecationWarning: Unrecognized location 'Upper Left'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.
#   import sys

# %% [markdown]
# # Part 2

# %%
# Free Throw Accuracy

# %%
myplot(FreeThrows/FreeThrowAttempts)
plt.show()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in true_divide
#   """Entry point for launching an IPython kernel.
# C:\Users\hp\anaconda3\lib\site-packages\ipykernel_launcher.py:7: MatplotlibDeprecationWarning: Unrecognized location 'Upper Left'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.
#   import sys

# %%
# Chris Pauls is highest chances are his team would get more points if he had more FTA's Free Throw Attempts

# %%
#FieldGoals
KobeBryant_FG =[978, 813, 775, 800, 716, 740, 574, 738, 31, 266]         
JoeJohnson_FG =[632, 536, 647, 620, 635, 514, 423, 445, 462, 446]    
LeBranJames_FG =[875, 772, 794, 789, 768, 758, 621, 765, 767, 624]   
CarmeloAntbony_FG =[756, 691, 728, 535, 688, 684, 441, 669, 743, 358]
DwightHoward_FG =[468, 526, 583, 560, 510, 619, 416, 470, 473, 251]  
Chrispaul_FG =[407, 728, 535, 688, 684, 441, 669, 743, 568, 568]         
KevinDurant_FG =[306, 306, 587, 661, 794, 711, 643, 731, 849, 238]   
DerricRose_FG =[208, 728, 535, 688, 684, 441, 669, 743, 0, 338, 338]     
DwayneWade_FG =[699, 472, 439, 854, 719, 692, 416, 569, 415, 509]    

#Matrix
FieldGoals = np.array([KobeBryant_FG, JoeJohnson_FG, LeBranJames_FG, CarmeloAntbony_FG, DwightHoward_FG, Chrisbosh_FG, Chrispaul_FG, KevinDurant_FG, DerricRose_FG, DwayneWade_FG])

#Field Goal Attempts
KobeBryant_FGA =[2173, 1757, 1690, 1712, 1569, 1639, 1336, 1595, 73, 713] 
JoeJohnson_FGA =[1395, 1139, 1497, 1420, 1386, 1161, 931, 1052, 1018, 1025]
LeBranJames_FGA =[1823, 1621, 1642, 1613, 1528, 1485, 1169, 1354, 1353, 1279]
CarmeloAntbony_FGA =[1572, 2941, 2941, 2941, 2941, 2941, 2941, 2941, 2941, 806]
DwightHoward_FGA =[881, 873, 974, 979, 834, 1044, 726, 813, 800, 423]   
Chrisbosh_FGA =[1087, 1094, 1027, 1263, 1158, 1056, 807, 907, 953, 745] 
Chrispaul_FGA =[947, 871, 1291, 1255,637, 928, 890, 856, 870, 1170]     
KevinDurant_FGA =[647, 647, 1366, 1390, 1668, 1538, 1297, 1433, 1688, 467]
DerricRose_FGA =[436, 436, 436, 1208, 1373, 1597, 695, 0, 164, 835]       
DwayneWade_FGA =[1413, 962, 937, 1739, 1511, 1384, 837, 1093, 761, 1084]   

#Matrix

FieldGoalAttempts = np.array([KobeBryant_FGA, JoeJohnson_FGA, LeBranJames_FGA, CarmeloAntbony_FGA, DwightHoward_FGA, Chrisbosh_FGA, Chrispaul_FGA, KevinDurant_FGA, DerricRose_FGA, DwayneWade_FGA])

# %%
myplot(FieldGoals/FieldGoalAttempts)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-91-2f377d0f5aa4> in <module>
# ----> 1 myplot(FieldGoals/FieldGoalAttempts)
#
# TypeError: unsupported operand type(s) for /: 'list' and 'int'
